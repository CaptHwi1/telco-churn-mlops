# %% [markdown]
# # 🎯 Telco Churn: Hyperparameter Tuning (Optuna + MLflow)
#
# **Objective**: Optimize XGBoost hyperparameters to maximize recall with precision constraint
#
# **Strategy**:
# - Use Optuna for Bayesian optimization (100 trials)
# - Track all trials with MLflow
# - Optimize recall while maintaining precision ≥ 0.35
# - Compare with baseline model performance
# - Export best model to MLflow Model Registry
#
# **Prerequisites**: Run `baseline_model.ipynb` first to establish baseline metrics
#
# ---
# *Run from project root with `source venv/bin/activate`*

# %%
# === 1. Setup & Imports ===
import pandas as pd
import numpy as np
import xgboost as xgb
import optuna
import mlflow
import mlflow.xgboost
from sklearn.model_selection import StratifiedKFold, cross_val_predict
from sklearn.metrics import recall_score, precision_score, f1_score, roc_auc_score
import matplotlib.pyplot as plt
import seaborn as sns
import json
from pathlib import Path
import sys
import warnings
from datetime import datetime

# Project setup
project_root = Path.cwd().parent.parent
if str(project_root / 'src') not in sys.path:
    sys.path.insert(0, str(project_root))

from src.config import settings
from src.features import fit_preprocessing_pipeline, transform_data, save_preprocessing_artifacts
from src.data import validate_data_quality

# Styling
sns.set_style('whitegrid')
plt.rcParams['figure.figsize'] = (12, 6)
warnings.filterwarnings('ignore')

RANDOM_STATE = 42
np.random.seed(RANDOM_STATE)

print(f"✅ Environment ready | Optuna: {optuna.__version__} | XGBoost: {xgb.__version__}")
# Out:
# ✅ Environment ready | Optuna: 4.8.0 | XGBoost: 3.2.0
# C:\Users\user\anaconda3.1\envs\mlops_env\Lib\site-packages\pandera\_pandas_deprecated.py:154: FutureWarning: Importing pandas-specific classes and functions from the
# top-level pandera module will be **removed in a future version of pandera**.
# If you're using pandera to validate pandas objects, we highly recommend updating
# your import:
#
# ```
# # old import
# import pandera as pa
#
# # new import
# import pandera.pandas as pa
# ```
#
# If you're using pandera to validate objects from other compatible libraries
# like pyspark or polars, see the supported libraries section of the documentation
# for more information on how to import pandera:
#
# https://pandera.readthedocs.io/en/stable/supported_libraries.html
#
# To disable this warning, set the environment variable:
#
# ```
# export DISABLE_PANDERA_IMPORT_WARNING=True
# ```
#
#   warnings.warn(_future_warning, FutureWarning)

# %%
# === 2. Configure MLflow ===
mlflow.set_tracking_uri(settings.mlflow_tracking_uri)
tuning_experiment = f"{settings.mlflow_experiment_name}_tuning"
mlflow.set_experiment(tuning_experiment)

print(f"🔗 MLflow Tracking: {settings.mlflow_tracking_uri}")
print(f"📊 Experiment: {tuning_experiment}")
# Out:
# 🔗 MLflow Tracking: http://localhost:5000
# 📊 Experiment: telco_churn_baseline_tuning

# %%
# === 3. Load Data ===
data_paths = [
    Path('..', '..', 'data', 'raw', 'telco.csv'),
    Path('..', 'data', 'raw', 'telco.csv'),
    Path('telco.csv')
]

data_file = next((p for p in data_paths if p.exists()), None)
if data_file is None:
    raise FileNotFoundError("telco.csv not found")

print(f"📁 Loading data from: {data_file}")
df = pd.read_csv(data_file)
print(f"✅ Loaded: {df.shape[0]:,} rows × {df.shape[1]} columns")

# Validate
quality_report = validate_data_quality(df)
print(f"   Quality Score: {quality_report['quality_score']:.1f}/100")
# Out:
# 📁 Loading data from: ..\..\data\raw\telco.csv
# ✅ Loaded: 7,043 rows × 50 columns
#    Quality Score: 85.0/100

# %%
# === SETUP: Load and Preprocess Data for Tuning ===
print("🔄 Loading and preprocessing data...")

from pathlib import Path
import pandas as pd
import numpy as np
from src.features.preprocessing import fit_preprocessing_pipeline, transform_data

# 1. Load raw data
data_paths = [
    Path('..', '..', 'data', 'raw', 'telco.csv'),
    Path('..', 'data', 'raw', 'telco.csv'),
    Path('data', 'raw', 'telco.csv'),
    Path('telco.csv')
]
data_file = next((p for p in data_paths if p.exists()), None)
if data_file is None:
    raise FileNotFoundError("telco.csv not found")

df = pd.read_csv(data_file)
print(f"✅ Loaded: {df.shape[0]:,} rows × {df.shape[1]} columns")

# 2. Define target and features
target_col = 'Churn Label'
EXCLUDE_COLS = [
    'Customer ID', 'Country', 'State', 'City', 'Zip Code',
    'Latitude', 'Longitude', 'Churn Label', 'Customer Status',
    'Churn Score', 'CLTV', 'Churn Category', 'Churn Reason',
    'Total Revenue', 'Total Refunds', 'Quarter'
]
feature_cols = [c for c in df.columns if c not in EXCLUDE_COLS]

X_df = df[feature_cols].copy()
# ✅ Encode target manually: 'Yes'→1, 'No'→0
y_df = df[target_col].map({'Yes': 1, 'No': 0}).fillna(0).astype(int)

print(f"✅ Features: {X_df.shape[1]}, Target: {y_df.value_counts().to_dict()}")

# 3. Fit preprocessing pipeline on RAW df (with ALL columns)
pipeline, feature_names, metadata = fit_preprocessing_pipeline(
    X_df,  
    target_col=target_col,  # ← Specify target column name
    validate=True
)

# 4. Transform data using fitted pipeline
X, _ = transform_data(df, pipeline, metadata, validate=False)
y = y_df
print(f"✅ Preprocessed: X={X.shape}, y={y.shape if y is not None else 'None'}")
if y is not None:
    print(f"✅ Target distribution: {pd.Series(y).value_counts().to_dict()}")

# 5. Verify data is ready
if X is None or y is None:
    raise ValueError("❌ X or y is None! Check preprocessing.")
if len(X) == 0 or len(y) == 0:
    raise ValueError("❌ X or y is empty! Check preprocessing.")
if not isinstance(y, (pd.Series, np.ndarray)):
    raise ValueError(f"❌ y has wrong type: {type(y)}")

print("✅ Data ready for hyperparameter tuning!")
# Out:
# 🔄 Loading and preprocessing data...
# ✅ Loaded: 7,043 rows × 50 columns
# ✅ Features: 34, Target: {0: 5174, 1: 1869}
#    Standardized columns: ['gender', 'age', 'under_30', 'senior_citizen', 'married']...
#    Numeric features: 9
#    Categorical features: 3
#    Total features after encoding: 39
#    Fitting pipeline...
#    ✅ Pipeline fitted successfully
# ✅ Preprocessed: X=(7043, 39), y=(7043,)
# ✅ Target distribution: {0: 5174, 1: 1869}
# ✅ Data ready for hyperparameter tuning!

# %%
# === 5. Load Baseline Metrics ===
baseline_path = Path('..', '..', 'artifacts', 'training_summary.json')
if baseline_path.exists():
    with open(baseline_path) as f:
        baseline = json.load(f)
    baseline_recall = float(baseline['cv_recall'].split(' ± ')[0])
    print(f"📊 Baseline Recall: {baseline_recall:.3f}")
else:
    baseline_recall = 0.85
    print(f"⚠️  Baseline not found, using default: {baseline_recall}")
# Out:
# 📊 Baseline Recall: 0.978

# %%
# === 6. Define Search Space (Conservative) ===
def define_search_space(trial):
    return {
        'max_depth': trial.suggest_int('max_depth', 3, 6),
        'learning_rate': trial.suggest_float('learning_rate', 0.05, 0.15, log=True),
        'n_estimators': trial.suggest_int('n_estimators', 100, 300),
        'subsample': trial.suggest_float('subsample', 0.7, 0.9),
        'colsample_bytree': trial.suggest_float('colsample_bytree', 0.7, 0.9),
        'min_child_weight': trial.suggest_int('min_child_weight', 1, 5),
        'gamma': trial.suggest_float('gamma', 0.0, 0.3),
        'reg_alpha': trial.suggest_float('reg_alpha', 0.0, 1.0),
        'reg_lambda': trial.suggest_float('reg_lambda', 0.5, 2.0),
    }

print("📋 Search Space:")
print("   max_depth: 3-6")
print("   learning_rate: 0.05-0.15")
print("   n_estimators: 100-300")
print("   subsample: 0.7-0.9")
# Out:
# 📋 Search Space:
#    max_depth: 3-6
#    learning_rate: 0.05-0.15
#    n_estimators: 100-300
#    subsample: 0.7-0.9

# %%
# === 7. Define Objective Function ===
N_TRIALS = 100
MIN_PRECISION = 0.35
CV_FOLDS = 5

cv = StratifiedKFold(n_splits=CV_FOLDS, shuffle=True, random_state=RANDOM_STATE)
n_neg = np.sum(y == 0)
n_pos = np.sum(y == 1)
scale_pos_weight = n_neg / n_pos if n_pos > 0 else 1.0

trial_results = []

def objective(trial):
    params = define_search_space(trial)
    params.update({
        'objective': 'binary:logistic',
        'eval_metric': 'logloss',
        'scale_pos_weight': scale_pos_weight,
        'random_state': RANDOM_STATE,
        'n_jobs': -1
    })
    
    with mlflow.start_run(nested=True, run_name=f"trial_{trial.number}"):
        mlflow.log_params(params)
        
        recalls, precisions = [], []
        
        for train_idx, val_idx in cv.split(X, y):
            X_train, X_val = X.iloc[train_idx], X.iloc[val_idx]
            y_train, y_val = y.iloc[train_idx], y.iloc[val_idx]
            
            # ✅ XGBoost 3.2.0: early_stopping_rounds in constructor, NOT fit()
            model = xgb.XGBClassifier(
                **params,
                early_stopping_rounds=20  # ← Constructor parameter
            )
            model.fit(
                X_train, y_train, 
                eval_set=[(X_val, y_val)],  # ← Required for early stopping
                verbose=False
            )
            
            y_pred_proba = model.predict_proba(X_val)[:, 1]
            
            # Find optimal threshold
            best_recall, best_thresh = 0, 0.5
            for thresh in np.arange(0.1, 0.9, 0.05):
                y_pred = (y_pred_proba >= thresh).astype(int)
                recall = recall_score(y_val, y_pred, zero_division=0)
                precision = precision_score(y_val, y_pred, zero_division=0)
                if precision >= MIN_PRECISION and recall > best_recall:
                    best_recall, best_thresh = recall, thresh
            
            y_pred_opt = (y_pred_proba >= best_thresh).astype(int)
            recalls.append(recall_score(y_val, y_pred_opt, zero_division=0))
            precisions.append(precision_score(y_val, y_pred_opt, zero_division=0))
        
        avg_recall = np.mean(recalls)
        avg_precision = np.mean(precisions)
        
        mlflow.log_metric("recall", avg_recall)
        mlflow.log_metric("precision", avg_precision)
        
        trial_results.append({
            'trial': trial.number,
            'recall': avg_recall,
            'precision': avg_precision,
            'params': params
        })
        
        # Penalize if precision constraint not met
        if avg_precision < MIN_PRECISION:
            return -1.0
        
        return avg_recall

print(f"🎯 Objective: Maximize Recall (Precision ≥ {MIN_PRECISION})")
print(f"📊 Trials: {N_TRIALS}")
# Out:
# 🎯 Objective: Maximize Recall (Precision ≥ 0.35)
# 📊 Trials: 100

# %%
# === 8. Run Optimization ===
print("\n🚀 Starting Optimization...")
print("=" * 60)

study = optuna.create_study(
    direction='maximize',
    study_name='telco_churn_tuning',
    pruner=optuna.pruners.MedianPruner(n_startup_trials=10)
)

start_time = datetime.now()
study.optimize(objective, n_trials=N_TRIALS, timeout=3600, show_progress_bar=True)
end_time = datetime.now()

print(f"\n✅ Optimization Complete!")
print(f"⏱️  Duration: {(end_time - start_time).total_seconds() / 60:.1f} minutes")
print(f"📊 Total Trials: {len(study.trials)}")
print(f"✅ Successful: {len([t for t in study.trials if t.value > 0])}")
# Out:
# [I 2026-04-03 09:46:06,568] A new study created in memory with name: telco_churn_tuning
# 🚀 Starting Optimization...
# ============================================================
#   0%|          | 0/100 [00:00<?, ?it/s]
# 🏃 View run trial_0 at: http://localhost:5000/#/experiments/2/runs/b7ef7f1064804096af9f2de0d655752e
# 🧪 View experiment at: http://localhost:5000/#/experiments/2
# [I 2026-04-03 09:46:12,837] Trial 0 finished with value: 0.9705667302260899 and parameters: {'max_depth': 5, 'learning_rate': 0.08485882961263617, 'n_estimators': 195, 'subsample': 0.8665715635435414, 'colsample_bytree': 0.7700092090439183, 'min_child_weight': 4, 'gamma': 0.23710713921885052, 'reg_alpha': 0.7492670272064939, 'reg_lambda': 1.3709711098654476}. Best is trial 0 with value: 0.9705667302260899.
# 🏃 View run trial_1 at: http://localhost:5000/#/experiments/2/runs/e8126f29df1b4379831ed65d05f2735b
# 🧪 View experiment at: http://localhost:5000/#/experiments/2
# [I 2026-04-03 09:46:15,634] Trial 1 finished with value: 0.9662857880173762 and parameters: {'max_depth': 5, 'learning_rate': 0.13020003173363234, 'n_estimators': 121, 'subsample': 0.7012223041666908, 'colsample_bytree': 0.8433380615177641, 'min_child_weight': 1, 'gamma': 0.15833478029419548, 'reg_alpha': 0.5164799066187957, 'reg_lambda': 1.9126526411778673}. Best is trial 0 with value: 0.9705667302260899.
# 🏃 View run trial_2 at: http://localhost:5000/#/experiments/2/runs/31aaa9cc6b65439983dcbc9772d65140
# 🧪 View experiment at: http://localhost:5000/#/experiments/2
# [I 2026-04-03 09:46:18,430] Trial 2 finished with value: 0.9716376826138692 and parameters: {'max_depth': 5, 'learning_rate': 0.09875736023588745, 'n_estimators': 241, 'subsample': 0.882280270076061, 'colsample_bytree': 0.7401584013228442, 'min_child_weight': 3, 'gamma': 0.04371917970374006, 'reg_alpha': 0.0971685294852519, 'reg_lambda': 1.1437986274999057}. Best is trial 2 with value: 0.9716376826138692.
# 🏃 View run trial_3 at: http://localhost:5000/#/experiments/2/runs/60a4a3fad0ed497ab09d9d8291719e44
# 🧪 View experiment at: http://localhost:5000/#/experiments/2
# [I 2026-04-03 09:46:20,501] Trial 3 finished with value: 0.9748491061060056 and parameters: {'max_depth': 5, 'learning_rate': 0.0744654824489119, 'n_estimators': 297, 'subsample': 0.7559344729915757, 'colsample_bytree': 0.866705272087609, 'min_child_weight': 3, 'gamma': 0.08493831872954995, 'reg_alpha': 0.19043639681230562, 'reg_lambda': 0.7893365575711595}. Best is trial 3 with value: 0.9748491061060056.
# 🏃 View run trial_4 at: http://localhost:5000/#/experiments/2/runs/14a2289ab766481698d5da949ae6dd45
# 🧪 View experiment at: http://localhost:5000/#/experiments/2
# [I 2026-04-03 09:46:22,498] Trial 4 finished with value: 0.9668219810468667 and parameters: {'max_depth': 6, 'learning_rate': 0.06745032705563941, 'n_estimators': 138, 'subsample': 0.8517390467081175, 'colsample_bytree': 0.8463865649320386, 'min_child_weight': 2, 'gamma': 0.21584439358918325, 'reg_alpha': 0.3949195976918126, 'reg_lambda': 0.8895282592325954}. Best is trial 3 with value: 0.9748491061060056.
# 🏃 View run trial_5 at: http://localhost:5000/#/experiments/2/runs/fa625dd99c3c43089e9f9ca3cb106894
# 🧪 View experiment at: http://localhost:5000/#/experiments/2
# [I 2026-04-03 09:46:24,300] Trial 5 finished with value: 0.9662886553597797 and parameters: {'max_depth': 5, 'learning_rate': 0.11960184717218292, 'n_estimators': 173, 'subsample': 0.8199641840367672, 'colsample_bytree': 0.7217492059874803, 'min_child_weight': 4, 'gamma': 0.0901849234541491, 'reg_alpha': 0.6118915159615924, 'reg_lambda': 1.6717244827140747}. Best is trial 3 with value: 0.9748491061060056.
# 🏃 View run trial_6 at: http://localhost:5000/#/experiments/2/runs/35755314408d42418728588f6ba504da
# 🧪 View experiment at: http://localhost:5000/#/experiments/2
# [I 2026-04-03 09:46:26,119] Trial 6 finished with value: 0.9759157574801793 and parameters: {'max_depth': 4, 'learning_rate': 0.13006006027146724, 'n_estimators': 216, 'subsample': 0.8545505496106761, 'colsample_bytree': 0.8526780232449153, 'min_child_weight': 4, 'gamma': 0.05746845942986747, 'reg_alpha': 0.030672038636034626, 'reg_lambda': 1.4640910363782371}. Best is trial 6 with value: 0.9759157574801793.
# 🏃 View run trial_7 at: http://localhost:5000/#/experiments/2/runs/a8da26b82c6148c4ae6e464977a0a142
# 🧪 View experiment at: http://localhost:5000/#/experiments/2
# [I 2026-04-03 09:46:27,851] Trial 7 finished with value: 0.9839457498817221 and parameters: {'max_depth': 3, 'learning_rate': 0.10823443895454596, 'n_estimators': 242, 'subsample': 0.731753269841966, 'colsample_bytree': 0.8105575606589857, 'min_child_weight': 2, 'gamma': 0.03803890013297965, 'reg_alpha': 0.44070994458008705, 'reg_lambda': 1.6778651162227969}. Best is trial 7 with value: 0.9839457498817221.
# 🏃 View run trial_8 at: http://localhost:5000/#/experiments/2/runs/a0b06c3d6143425a85f055e8d009a711
# 🧪 View experiment at: http://localhost:5000/#/experiments/2
# [I 2026-04-03 09:46:29,532] Trial 8 finished with value: 0.9876933664033489 and parameters: {'max_depth': 3, 'learning_rate': 0.09601696433012093, 'n_estimators': 133, 'subsample': 0.8094847069942757, 'colsample_bytree': 0.8934276883899954, 'min_child_weight': 5, 'gamma': 0.1457009916934712, 'reg_alpha': 0.7355889441750253, 'reg_lambda': 0.7720191806455567}. Best is trial 8 with value: 0.9876933664033489.
# 🏃 View run trial_9 at: http://localhost:5000/#/experiments/2/runs/06479a8c59d843b4a07f6b9869619af1
# 🧪 View experiment at: http://localhost:5000/#/experiments/2
# [I 2026-04-03 09:46:31,489] Trial 9 finished with value: 0.9892976444782153 and parameters: {'max_depth': 3, 'learning_rate': 0.05962294772901181, 'n_estimators': 157, 'subsample': 0.7551546747249207, 'colsample_bytree': 0.8038558754017554, 'min_child_weight': 5, 'gamma': 0.29605320319097417, 'reg_alpha': 0.15911022264900476, 'reg_lambda': 0.6638004827469093}. Best is trial 9 with value: 0.9892976444782153.
# 🏃 View run trial_10 at: http://localhost:5000/#/experiments/2/runs/6663a5f5dbf249168bc5f2a00bcb4b99
# 🧪 View experiment at: http://localhost:5000/#/experiments/2
# [I 2026-04-03 09:46:33,498] Trial 10 finished with value: 0.9887628851199265 and parameters: {'max_depth': 3, 'learning_rate': 0.051236727292781434, 'n_estimators': 165, 'subsample': 0.7682171387439023, 'colsample_bytree': 0.7982716223231962, 'min_child_weight': 5, 'gamma': 0.29197017537814574, 'reg_alpha': 0.9801477834459813, 'reg_lambda': 0.5023582244055309}. Best is trial 9 with value: 0.9892976444782153.
# 🏃 View run trial_11 at: http://localhost:5000/#/experiments/2/runs/7f4198199ca1402b9c1ea6eb8e245e37
# 🧪 View experiment at: http://localhost:5000/#/experiments/2
# [I 2026-04-03 09:46:35,507] Trial 11 finished with value: 0.9887628851199265 and parameters: {'max_depth': 3, 'learning_rate': 0.05010180608207192, 'n_estimators': 166, 'subsample': 0.7696283295236367, 'colsample_bytree': 0.7980814682181573, 'min_child_weight': 5, 'gamma': 0.2950359192088374, 'reg_alpha': 0.9873204067429668, 'reg_lambda': 0.5041921194486637}. Best is trial 9 with value: 0.9892976444782153.
# 🏃 View run trial_12 at: http://localhost:5000/#/experiments/2/runs/9e7a4998a26543be8dfc16099b8f1e8f
# 🧪 View experiment at: http://localhost:5000/#/experiments/2
# [I 2026-04-03 09:46:37,605] Trial 12 finished with value: 0.983947183552924 and parameters: {'max_depth': 4, 'learning_rate': 0.05027003044661867, 'n_estimators': 162, 'subsample': 0.7730065372226593, 'colsample_bytree': 0.7989851829741458, 'min_child_weight': 5, 'gamma': 0.29364211340605967, 'reg_alpha': 0.9864513571894867, 'reg_lambda': 0.5059624609295066}. Best is trial 9 with value: 0.9892976444782153.
# 🏃 View run trial_13 at: http://localhost:5000/#/experiments/2/runs/1bd09dffb12a48889100c3fe2eb8e474
# 🧪 View experiment at: http://localhost:5000/#/experiments/2
# [I 2026-04-03 09:46:39,283] Trial 13 finished with value: 0.9919728749408611 and parameters: {'max_depth': 3, 'learning_rate': 0.059951183112069324, 'n_estimators': 113, 'subsample': 0.7355360033785006, 'colsample_bytree': 0.7647064700597426, 'min_child_weight': 5, 'gamma': 0.2422213337701559, 'reg_alpha': 0.2595403963245345, 'reg_lambda': 1.022408375693703}. Best is trial 13 with value: 0.9919728749408611.
# 🏃 View run trial_14 at: http://localhost:5000/#/experiments/2/runs/59d3319e9c254b6e87bf548482375dbb
# 🧪 View experiment at: http://localhost:5000/#/experiments/2
# [I 2026-04-03 09:46:40,994] Trial 14 finished with value: 0.9850195696119052 and parameters: {'max_depth': 4, 'learning_rate': 0.0635165865430576, 'n_estimators': 103, 'subsample': 0.7263459779641736, 'colsample_bytree': 0.7508878803365896, 'min_child_weight': 4, 'gamma': 0.23681453997653257, 'reg_alpha': 0.28072943262401534, 'reg_lambda': 1.0689638895627125}. Best is trial 13 with value: 0.9919728749408611.
# 🏃 View run trial_15 at: http://localhost:5000/#/experiments/2/runs/1fbdbc7487d74b0596a0593e9094efc3
# 🧪 View experiment at: http://localhost:5000/#/experiments/2
# [I 2026-04-03 09:46:42,584] Trial 15 finished with value: 0.9914381155825722 and parameters: {'max_depth': 3, 'learning_rate': 0.06032168399995177, 'n_estimators': 102, 'subsample': 0.7258359883625132, 'colsample_bytree': 0.770268514017891, 'min_child_weight': 5, 'gamma': 0.1895866572478752, 'reg_alpha': 0.26412359521906636, 'reg_lambda': 0.9682910896282}. Best is trial 13 with value: 0.9919728749408611.
# 🏃 View run trial_16 at: http://localhost:5000/#/experiments/2/runs/03cd4e33d4204542867333991acae627
# 🧪 View experiment at: http://localhost:5000/#/experiments/2
# [I 2026-04-03 09:46:44,230] Trial 16 finished with value: 0.9839486172241259 and parameters: {'max_depth': 4, 'learning_rate': 0.0748195049024522, 'n_estimators': 101, 'subsample': 0.7064445531969462, 'colsample_bytree': 0.7724338283580289, 'min_child_weight': 4, 'gamma': 0.1975870142179503, 'reg_alpha': 0.2997749691636155, 'reg_lambda': 0.9867148962124024}. Best is trial 13 with value: 0.9919728749408611.
# 🏃 View run trial_17 at: http://localhost:5000/#/experiments/2/runs/96312f8fc230414ca3debb29872a909b
# 🧪 View experiment at: http://localhost:5000/#/experiments/2
# [I 2026-04-03 09:46:46,328] Trial 17 finished with value: 0.9737824547318319 and parameters: {'max_depth': 6, 'learning_rate': 0.05849129818637186, 'n_estimators': 130, 'subsample': 0.728798815215049, 'colsample_bytree': 0.7237073031626041, 'min_child_weight': 3, 'gamma': 0.16590823337810415, 'reg_alpha': 0.2848676590191682, 'reg_lambda': 1.2570371091405323}. Best is trial 13 with value: 0.9919728749408611.
# 🏃 View run trial_18 at: http://localhost:5000/#/experiments/2/runs/d495dcb9da264cf8a14938170243dc45
# 🧪 View experiment at: http://localhost:5000/#/experiments/2
# [I 2026-04-03 09:46:47,971] Trial 18 finished with value: 0.9882281257616377 and parameters: {'max_depth': 3, 'learning_rate': 0.07921807051937751, 'n_estimators': 115, 'subsample': 0.7877526471998719, 'colsample_bytree': 0.7667033328126007, 'min_child_weight': 2, 'gamma': 0.2510091111863429, 'reg_alpha': 0.5759532334637489, 'reg_lambda': 1.2021833360713594}. Best is trial 13 with value: 0.9919728749408611.
# 🏃 View run trial_19 at: http://localhost:5000/#/experiments/2/runs/27374616ea684d4497d1af2c6e6d2295
# 🧪 View experiment at: http://localhost:5000/#/experiments/2
# [I 2026-04-03 09:46:50,435] Trial 19 finished with value: 0.9775286375822569 and parameters: {'max_depth': 4, 'learning_rate': 0.06775701300737608, 'n_estimators': 292, 'subsample': 0.7412988800812133, 'colsample_bytree': 0.8232446934355218, 'min_child_weight': 5, 'gamma': 0.1286994979428583, 'reg_alpha': 0.005642471803018467, 'reg_lambda': 0.9641565948750012}. Best is trial 13 with value: 0.9919728749408611.
# 🏃 View run trial_20 at: http://localhost:5000/#/experiments/2/runs/a1203a8e7bd0495da5a4db3ecf7f843a
# 🧪 View experiment at: http://localhost:5000/#/experiments/2
# [I 2026-04-03 09:46:53,163] Trial 20 finished with value: 0.9866238476867715 and parameters: {'max_depth': 3, 'learning_rate': 0.058042814050405345, 'n_estimators': 196, 'subsample': 0.8287107495272225, 'colsample_bytree': 0.7468125159874008, 'min_child_weight': 3, 'gamma': 0.1924892792918481, 'reg_alpha': 0.3768487176115865, 'reg_lambda': 1.4002292646057493}. Best is trial 13 with value: 0.9919728749408611.
# 🏃 View run trial_21 at: http://localhost:5000/#/experiments/2/runs/5e71470172b444999c1f98d3b42aa48a
# 🧪 View experiment at: http://localhost:5000/#/experiments/2
# [I 2026-04-03 09:46:55,218] Trial 21 finished with value: 0.9882309931040414 and parameters: {'max_depth': 3, 'learning_rate': 0.057826987641286895, 'n_estimators': 154, 'subsample': 0.7493599712545217, 'colsample_bytree': 0.7016256127595231, 'min_child_weight': 5, 'gamma': 0.2611559218039654, 'reg_alpha': 0.147119932768343, 'reg_lambda': 0.691044072771118}. Best is trial 13 with value: 0.9919728749408611.
# 🏃 View run trial_22 at: http://localhost:5000/#/experiments/2/runs/1c756b31b3774e688d0c1f5eecd49da1
# 🧪 View experiment at: http://localhost:5000/#/experiments/2
# [I 2026-04-03 09:46:57,170] Trial 22 finished with value: 0.989833837507706 and parameters: {'max_depth': 3, 'learning_rate': 0.06367160753190021, 'n_estimators': 144, 'subsample': 0.7157351505059125, 'colsample_bytree': 0.7843681120538326, 'min_child_weight': 5, 'gamma': 0.26286216433951437, 'reg_alpha': 0.2085689707756606, 'reg_lambda': 0.6927912553201141}. Best is trial 13 with value: 0.9919728749408611.
# 🏃 View run trial_23 at: http://localhost:5000/#/experiments/2/runs/dcc6c5b0396f413fbece94ce2517ab28
# 🧪 View experiment at: http://localhost:5000/#/experiments/2
# [I 2026-04-03 09:46:59,190] Trial 23 finished with value: 0.979667675015412 and parameters: {'max_depth': 4, 'learning_rate': 0.06802092301655119, 'n_estimators': 145, 'subsample': 0.7109440434929731, 'colsample_bytree': 0.7787405464219681, 'min_child_weight': 4, 'gamma': 0.207861342400041, 'reg_alpha': 0.23363989251359252, 'reg_lambda': 0.8454724495103566}. Best is trial 13 with value: 0.9919728749408611.
# 🏃 View run trial_24 at: http://localhost:5000/#/experiments/2/runs/b4745305f753411386770291abab83f2
# 🧪 View experiment at: http://localhost:5000/#/experiments/2
# [I 2026-04-03 09:47:00,761] Trial 24 finished with value: 0.9860862209860789 and parameters: {'max_depth': 3, 'learning_rate': 0.14775657121491248, 'n_estimators': 114, 'subsample': 0.7303128923828158, 'colsample_bytree': 0.7849275561027549, 'min_child_weight': 5, 'gamma': 0.2553739275308417, 'reg_alpha': 0.3544197935555772, 'reg_lambda': 1.0427869663848623}. Best is trial 13 with value: 0.9919728749408611.
# 🏃 View run trial_25 at: http://localhost:5000/#/experiments/2/runs/2e01f27403624c4b93eb64db5937a146
# 🧪 View experiment at: http://localhost:5000/#/experiments/2
# [I 2026-04-03 09:47:03,129] Trial 25 finished with value: 0.9914395492537741 and parameters: {'max_depth': 3, 'learning_rate': 0.05462694985400121, 'n_estimators': 100, 'subsample': 0.7164395327787924, 'colsample_bytree': 0.7582822287203199, 'min_child_weight': 4, 'gamma': 0.18505272632110736, 'reg_alpha': 0.0901969615314116, 'reg_lambda': 0.6567563012118085}. Best is trial 13 with value: 0.9919728749408611.
# 🏃 View run trial_26 at: http://localhost:5000/#/experiments/2/runs/d09fe4e43b6d42bb878076392eb52d63
# 🧪 View experiment at: http://localhost:5000/#/experiments/2
# [I 2026-04-03 09:47:04,854] Trial 26 finished with value: 0.987693366403349 and parameters: {'max_depth': 4, 'learning_rate': 0.055506837101218946, 'n_estimators': 102, 'subsample': 0.7943871667854725, 'colsample_bytree': 0.7620075931705775, 'min_child_weight': 4, 'gamma': 0.18231995724878575, 'reg_alpha': 0.08720489750615971, 'reg_lambda': 0.866201736087584}. Best is trial 13 with value: 0.9919728749408611.
# 🏃 View run trial_27 at: http://localhost:5000/#/experiments/2/runs/fb8f599c46bc4dd5977a3ddbae32c720
# 🧪 View experiment at: http://localhost:5000/#/experiments/2
# [I 2026-04-03 09:47:06,618] Trial 27 finished with value: 0.9914395492537741 and parameters: {'max_depth': 3, 'learning_rate': 0.05520791030283736, 'n_estimators': 121, 'subsample': 0.7449746140859906, 'colsample_bytree': 0.7326332504012245, 'min_child_weight': 4, 'gamma': 0.2241943996894609, 'reg_alpha': 0.08635987087888955, 'reg_lambda': 0.6208129215512375}. Best is trial 13 with value: 0.9919728749408611.
# 🏃 View run trial_28 at: http://localhost:5000/#/experiments/2/runs/5f55e1a4907c4a50abe3f5f444dca728
# 🧪 View experiment at: http://localhost:5000/#/experiments/2
# [I 2026-04-03 09:47:09,061] Trial 28 finished with value: 0.9802038680449027 and parameters: {'max_depth': 4, 'learning_rate': 0.054366345666463124, 'n_estimators': 184, 'subsample': 0.7825550068806058, 'colsample_bytree': 0.730561306371826, 'min_child_weight': 4, 'gamma': 0.22361703648458625, 'reg_alpha': 0.09858060655008673, 'reg_lambda': 0.6259130778681891}. Best is trial 13 with value: 0.9919728749408611.
# 🏃 View run trial_29 at: http://localhost:5000/#/experiments/2/runs/108c98873f04485597919d7de86433c7
# 🧪 View experiment at: http://localhost:5000/#/experiments/2
# [I 2026-04-03 09:47:10,801] Trial 29 finished with value: 0.9871557397026566 and parameters: {'max_depth': 3, 'learning_rate': 0.08504724365343705, 'n_estimators': 122, 'subsample': 0.7499810993092524, 'colsample_bytree': 0.7027206255966053, 'min_child_weight': 4, 'gamma': 0.005893541438616257, 'reg_alpha': 0.04482701868186806, 'reg_lambda': 0.6289039645240629}. Best is trial 13 with value: 0.9919728749408611.
# 🏃 View run trial_30 at: http://localhost:5000/#/experiments/2/runs/64eb270f2c9341c8823d5d523581bf7a
# 🧪 View experiment at: http://localhost:5000/#/experiments/2
# [I 2026-04-03 09:47:12,672] Trial 30 finished with value: 0.989833837507706 and parameters: {'max_depth': 3, 'learning_rate': 0.07216821738579647, 'n_estimators': 128, 'subsample': 0.7186459569534089, 'colsample_bytree': 0.7523048143573422, 'min_child_weight': 4, 'gamma': 0.23507689973058682, 'reg_alpha': 0.1483531982872821, 'reg_lambda': 1.2904971412040185}. Best is trial 13 with value: 0.9919728749408611.
# 🏃 View run trial_31 at: http://localhost:5000/#/experiments/2/runs/369f73a9f31f4183b81161c1f756678e
# 🧪 View experiment at: http://localhost:5000/#/experiments/2
# [I 2026-04-03 09:47:14,314] Trial 31 finished with value: 0.9914381155825722 and parameters: {'max_depth': 3, 'learning_rate': 0.06268227251294099, 'n_estimators': 112, 'subsample': 0.7387919959329778, 'colsample_bytree': 0.760087724288806, 'min_child_weight': 5, 'gamma': 0.17896072457595294, 'reg_alpha': 0.2508407471645929, 'reg_lambda': 0.9266311328760144}. Best is trial 13 with value: 0.9919728749408611.
# 🏃 View run trial_32 at: http://localhost:5000/#/experiments/2/runs/481814f4668844b58832c928f462ab45
# 🧪 View experiment at: http://localhost:5000/#/experiments/2
# [I 2026-04-03 09:47:16,190] Trial 32 finished with value: 0.9909047898954852 and parameters: {'max_depth': 3, 'learning_rate': 0.05259556922183899, 'n_estimators': 119, 'subsample': 0.7052140461446265, 'colsample_bytree': 0.7389842450941136, 'min_child_weight': 4, 'gamma': 0.14114368589488124, 'reg_alpha': 0.4539420622638486, 'reg_lambda': 1.1044594313887395}. Best is trial 13 with value: 0.9919728749408611.
# 🏃 View run trial_33 at: http://localhost:5000/#/experiments/2/runs/b12a155dfffa423a8fb8876890530c21
# 🧪 View experiment at: http://localhost:5000/#/experiments/2
# [I 2026-04-03 09:47:17,980] Trial 33 finished with value: 0.991440982924976 and parameters: {'max_depth': 3, 'learning_rate': 0.05552403749447588, 'n_estimators': 102, 'subsample': 0.7212653814321088, 'colsample_bytree': 0.7320877892531874, 'min_child_weight': 1, 'gamma': 0.12068811985434785, 'reg_alpha': 0.09414292596058646, 'reg_lambda': 0.7553789613621193}. Best is trial 13 with value: 0.9919728749408611.
# 🏃 View run trial_34 at: http://localhost:5000/#/experiments/2/runs/ddc9dd44824f47a8ac73aefd0aa99bdc
# 🧪 View experiment at: http://localhost:5000/#/experiments/2
# [I 2026-04-03 09:47:19,995] Trial 34 finished with value: 0.9893005118206191 and parameters: {'max_depth': 3, 'learning_rate': 0.05567850897481467, 'n_estimators': 146, 'subsample': 0.7014302142673723, 'colsample_bytree': 0.7329467623508468, 'min_child_weight': 2, 'gamma': 0.10561666728947247, 'reg_alpha': 0.08781312039281317, 'reg_lambda': 0.7567831450424104}. Best is trial 13 with value: 0.9919728749408611.
# 🏃 View run trial_35 at: http://localhost:5000/#/experiments/2/runs/fa0747400300421a8b91f73696c3f4b8
# 🧪 View experiment at: http://localhost:5000/#/experiments/2
# [I 2026-04-03 09:47:21,880] Trial 35 finished with value: 0.9828805321787503 and parameters: {'max_depth': 4, 'learning_rate': 0.05409742529422171, 'n_estimators': 126, 'subsample': 0.7408718743848913, 'colsample_bytree': 0.7119380345866168, 'min_child_weight': 1, 'gamma': 0.11278437453454648, 'reg_alpha': 0.12354478700224954, 'reg_lambda': 0.5655568876193466}. Best is trial 13 with value: 0.9919728749408611.
# 🏃 View run trial_36 at: http://localhost:5000/#/experiments/2/runs/b4a563e5549e4278a8f12d8f7172ce3c
# 🧪 View experiment at: http://localhost:5000/#/experiments/2
# [I 2026-04-03 09:47:24,339] Trial 36 finished with value: 0.9673596077475592 and parameters: {'max_depth': 5, 'learning_rate': 0.06441249879027727, 'n_estimators': 215, 'subsample': 0.8843162650434486, 'colsample_bytree': 0.7185036984978829, 'min_child_weight': 1, 'gamma': 0.16845791382662514, 'reg_alpha': 0.005953848660558841, 'reg_lambda': 0.7993839927603481}. Best is trial 13 with value: 0.9919728749408611.
# 🏃 View run trial_37 at: http://localhost:5000/#/experiments/2/runs/08132f7e1b674ae48294a570fb36fdb0
# 🧪 View experiment at: http://localhost:5000/#/experiments/2
# [I 2026-04-03 09:47:26,265] Trial 37 finished with value: 0.9694957778383106 and parameters: {'max_depth': 6, 'learning_rate': 0.09364108488626763, 'n_estimators': 113, 'subsample': 0.7638860792467985, 'colsample_bytree': 0.7404884523527867, 'min_child_weight': 3, 'gamma': 0.21702622041247796, 'reg_alpha': 0.18757745921486876, 'reg_lambda': 0.7449930703803403}. Best is trial 13 with value: 0.9919728749408611.
# 🏃 View run trial_38 at: http://localhost:5000/#/experiments/2/runs/e8afb2ed30e940b7a4291e7d3a0eb32b
# 🧪 View experiment at: http://localhost:5000/#/experiments/2
# [I 2026-04-03 09:47:28,632] Trial 38 finished with value: 0.9818052787773652 and parameters: {'max_depth': 3, 'learning_rate': 0.07932087602245598, 'n_estimators': 245, 'subsample': 0.7173452295640517, 'colsample_bytree': 0.754801241132942, 'min_child_weight': 1, 'gamma': 0.271279977128194, 'reg_alpha': 0.05946237762508405, 'reg_lambda': 0.6073743592388372}. Best is trial 13 with value: 0.9919728749408611.
# 🏃 View run trial_39 at: http://localhost:5000/#/experiments/2/runs/dee3f32dfae1413c9d55b207c62b8f09
# 🧪 View experiment at: http://localhost:5000/#/experiments/2
# [I 2026-04-03 09:47:30,698] Trial 39 finished with value: 0.9764562515232758 and parameters: {'max_depth': 5, 'learning_rate': 0.05311590708517065, 'n_estimators': 138, 'subsample': 0.7384102535187919, 'colsample_bytree': 0.7315457975510176, 'min_child_weight': 3, 'gamma': 0.07345656675081559, 'reg_alpha': 0.32400603418210716, 'reg_lambda': 0.8604058901120375}. Best is trial 13 with value: 0.9919728749408611.
# 🏃 View run trial_40 at: http://localhost:5000/#/experiments/2/runs/2ef62aad59fd4fe6bf2f1281ef2b7322
# 🧪 View experiment at: http://localhost:5000/#/experiments/2
# [I 2026-04-03 09:47:32,810] Trial 40 finished with value: 0.9876948000745509 and parameters: {'max_depth': 3, 'learning_rate': 0.07098039541990768, 'n_estimators': 183, 'subsample': 0.7582509414556028, 'colsample_bytree': 0.8290883888108445, 'min_child_weight': 3, 'gamma': 0.13440444631032714, 'reg_alpha': 0.19286327660254937, 'reg_lambda': 1.8822437160618486}. Best is trial 13 with value: 0.9919728749408611.
# 🏃 View run trial_41 at: http://localhost:5000/#/experiments/2/runs/a4094e4dd3bd401f90b4963db42642a4
# 🧪 View experiment at: http://localhost:5000/#/experiments/2
# [I 2026-04-03 09:47:34,632] Trial 41 finished with value: 0.9914381155825722 and parameters: {'max_depth': 3, 'learning_rate': 0.06151309375796328, 'n_estimators': 107, 'subsample': 0.7233925215953754, 'colsample_bytree': 0.7752363319615502, 'min_child_weight': 2, 'gamma': 0.15378528365571376, 'reg_alpha': 0.24696198368090178, 'reg_lambda': 1.1638912792591962}. Best is trial 13 with value: 0.9919728749408611.
# 🏃 View run trial_42 at: http://localhost:5000/#/experiments/2/runs/2da64a266bec42c0947684961f3f0e01
# 🧪 View experiment at: http://localhost:5000/#/experiments/2
# [I 2026-04-03 09:47:36,347] Trial 42 finished with value: 0.9914381155825722 and parameters: {'max_depth': 3, 'learning_rate': 0.06003791411104731, 'n_estimators': 100, 'subsample': 0.7476215892396414, 'colsample_bytree': 0.7417119514457415, 'min_child_weight': 5, 'gamma': 0.2038599593484728, 'reg_alpha': 0.486051345351572, 'reg_lambda': 1.0042246974719748}. Best is trial 13 with value: 0.9919728749408611.
# 🏃 View run trial_43 at: http://localhost:5000/#/experiments/2/runs/f5d2a5807aba4074b0a8f29b5baf11df
# 🧪 View experiment at: http://localhost:5000/#/experiments/2
# [I 2026-04-03 09:47:38,439] Trial 43 finished with value: 0.9903700305371966 and parameters: {'max_depth': 3, 'learning_rate': 0.05695422764160295, 'n_estimators': 121, 'subsample': 0.7320999629014898, 'colsample_bytree': 0.7863586329063192, 'min_child_weight': 4, 'gamma': 0.18457477692412122, 'reg_alpha': 0.05831538368206211, 'reg_lambda': 0.9099151017480915}. Best is trial 13 with value: 0.9919728749408611.
# 🏃 View run trial_44 at: http://localhost:5000/#/experiments/2/runs/688f33da71da45e78dd0e0bb6732a816
# 🧪 View experiment at: http://localhost:5000/#/experiments/2
# [I 2026-04-03 09:47:40,119] Trial 44 finished with value: 0.9903685968659947 and parameters: {'max_depth': 3, 'learning_rate': 0.06631109069878623, 'n_estimators': 109, 'subsample': 0.711632687408361, 'colsample_bytree': 0.7659040998851765, 'min_child_weight': 5, 'gamma': 0.22262530347533327, 'reg_alpha': 0.833973948798749, 'reg_lambda': 0.7156653336759176}. Best is trial 13 with value: 0.9919728749408611.
# 🏃 View run trial_45 at: http://localhost:5000/#/experiments/2/runs/ad3c1f7537c744b28360db252fe0efcf
# 🧪 View experiment at: http://localhost:5000/#/experiments/2
# [I 2026-04-03 09:47:41,950] Trial 45 finished with value: 0.9828762311651446 and parameters: {'max_depth': 3, 'learning_rate': 0.10939258432014987, 'n_estimators': 133, 'subsample': 0.7002047324163625, 'colsample_bytree': 0.7181934913952295, 'min_child_weight': 4, 'gamma': 0.11418728716054591, 'reg_alpha': 0.11798856488852641, 'reg_lambda': 0.8159758241138692}. Best is trial 13 with value: 0.9919728749408611.
# 🏃 View run trial_46 at: http://localhost:5000/#/experiments/2/runs/b14d786ded8d4090a19fa76a13a8b89a
# 🧪 View experiment at: http://localhost:5000/#/experiments/2
# [I 2026-04-03 09:47:44,600] Trial 46 finished with value: 0.9844805092400108 and parameters: {'max_depth': 3, 'learning_rate': 0.0520466884648855, 'n_estimators': 279, 'subsample': 0.7193234493133176, 'colsample_bytree': 0.8810666032053234, 'min_child_weight': 5, 'gamma': 0.23692293780070056, 'reg_alpha': 0.4103679249408232, 'reg_lambda': 1.5792078106137724}. Best is trial 13 with value: 0.9919728749408611.
# 🏃 View run trial_47 at: http://localhost:5000/#/experiments/2/runs/9fe4816f272d45a8aa4e001d014e682f
# 🧪 View experiment at: http://localhost:5000/#/experiments/2
# [I 2026-04-03 09:47:46,323] Trial 47 finished with value: 0.9860890883284827 and parameters: {'max_depth': 4, 'learning_rate': 0.06004584036639594, 'n_estimators': 100, 'subsample': 0.8371224100021262, 'colsample_bytree': 0.7572589722450743, 'min_child_weight': 2, 'gamma': 0.27493924550054843, 'reg_alpha': 0.32884924020149997, 'reg_lambda': 0.5535674235605031}. Best is trial 13 with value: 0.9919728749408611.
# 🏃 View run trial_48 at: http://localhost:5000/#/experiments/2/runs/a15b74e460c34590b571744aa27af24d
# 🧪 View experiment at: http://localhost:5000/#/experiments/2
# [I 2026-04-03 09:47:48,180] Trial 48 finished with value: 0.9914381155825722 and parameters: {'max_depth': 3, 'learning_rate': 0.05589901703880388, 'n_estimators': 123, 'subsample': 0.7603852114858872, 'colsample_bytree': 0.7914338798624472, 'min_child_weight': 5, 'gamma': 0.16233113054536258, 'reg_alpha': 0.5572661927067891, 'reg_lambda': 0.9246694084393214}. Best is trial 13 with value: 0.9919728749408611.
# 🏃 View run trial_49 at: http://localhost:5000/#/experiments/2/runs/4a3fe3c1d11b42419628285c02ea45f7
# 🧪 View experiment at: http://localhost:5000/#/experiments/2
# [I 2026-04-03 09:47:50,178] Trial 49 finished with value: 0.985554328970194 and parameters: {'max_depth': 4, 'learning_rate': 0.05042989602048488, 'n_estimators': 137, 'subsample': 0.8052147490725386, 'colsample_bytree': 0.7484728655278936, 'min_child_weight': 4, 'gamma': 0.20951167124497203, 'reg_alpha': 0.16927039704763175, 'reg_lambda': 1.1094474516308428}. Best is trial 13 with value: 0.9919728749408611.
# 🏃 View run trial_50 at: http://localhost:5000/#/experiments/2/runs/12957e2e0a814776855cc2c712339760
# 🧪 View experiment at: http://localhost:5000/#/experiments/2
# [I 2026-04-03 09:47:51,854] Trial 50 finished with value: 0.9887614514487246 and parameters: {'max_depth': 3, 'learning_rate': 0.08995338273277212, 'n_estimators': 109, 'subsample': 0.8696036995726519, 'colsample_bytree': 0.7696253435016328, 'min_child_weight': 5, 'gamma': 0.08702540299918954, 'reg_alpha': 0.2104668886426631, 'reg_lambda': 0.7681201424922411}. Best is trial 13 with value: 0.9919728749408611.
# 🏃 View run trial_51 at: http://localhost:5000/#/experiments/2/runs/870c0d226c5e479d9a1741a6544d9c7f
# 🧪 View experiment at: http://localhost:5000/#/experiments/2
# [I 2026-04-03 09:47:53,578] Trial 51 finished with value: 0.9909033562242835 and parameters: {'max_depth': 3, 'learning_rate': 0.06246913467003877, 'n_estimators': 113, 'subsample': 0.7354130291142822, 'colsample_bytree': 0.8102285002662705, 'min_child_weight': 5, 'gamma': 0.18093579469700433, 'reg_alpha': 0.25516786071990244, 'reg_lambda': 0.9548856668294252}. Best is trial 13 with value: 0.9919728749408611.
# 🏃 View run trial_52 at: http://localhost:5000/#/experiments/2/runs/167803b628a14867a6280b8b1d836340
# 🧪 View experiment at: http://localhost:5000/#/experiments/2
# [I 2026-04-03 09:47:55,308] Trial 52 finished with value: 0.9903685968659947 and parameters: {'max_depth': 3, 'learning_rate': 0.06515490896640407, 'n_estimators': 117, 'subsample': 0.7255971764125815, 'colsample_bytree': 0.7609910940978539, 'min_child_weight': 5, 'gamma': 0.1735887876669954, 'reg_alpha': 0.7121919392831408, 'reg_lambda': 1.0496900040748756}. Best is trial 13 with value: 0.9919728749408611.
# 🏃 View run trial_53 at: http://localhost:5000/#/experiments/2/runs/2b50a13238da44009dfdc96ec54337c5
# 🧪 View experiment at: http://localhost:5000/#/experiments/2
# [I 2026-04-03 09:47:56,985] Trial 53 finished with value: 0.9903685968659947 and parameters: {'max_depth': 3, 'learning_rate': 0.061400339839172535, 'n_estimators': 108, 'subsample': 0.7436143370645274, 'colsample_bytree': 0.7459433385218948, 'min_child_weight': 5, 'gamma': 0.19108638812553916, 'reg_alpha': 0.2717162393503676, 'reg_lambda': 0.9014368355094586}. Best is trial 13 with value: 0.9919728749408611.
# 🏃 View run trial_54 at: http://localhost:5000/#/experiments/2/runs/e94fa88717d4428ebab59449a104082b
# 🧪 View experiment at: http://localhost:5000/#/experiments/2
# [I 2026-04-03 09:47:58,847] Trial 54 finished with value: 0.9887643187911284 and parameters: {'max_depth': 3, 'learning_rate': 0.06995157132707241, 'n_estimators': 128, 'subsample': 0.7753746286509381, 'colsample_bytree': 0.7302695653470744, 'min_child_weight': 3, 'gamma': 0.15107189563039872, 'reg_alpha': 0.13243297730142134, 'reg_lambda': 0.6678896168502486}. Best is trial 13 with value: 0.9919728749408611.
# 🏃 View run trial_55 at: http://localhost:5000/#/experiments/2/runs/12d16954caec43378d0ad1f4f4713230
# 🧪 View experiment at: http://localhost:5000/#/experiments/2
# [I 2026-04-03 09:48:00,556] Trial 55 finished with value: 0.9909033562242835 and parameters: {'max_depth': 3, 'learning_rate': 0.05831795486729435, 'n_estimators': 108, 'subsample': 0.7548705307482577, 'colsample_bytree': 0.7106722391936371, 'min_child_weight': 5, 'gamma': 0.19920031310545874, 'reg_alpha': 0.22196048469010426, 'reg_lambda': 0.9983443314311746}. Best is trial 13 with value: 0.9919728749408611.
# 🏃 View run trial_56 at: http://localhost:5000/#/experiments/2/runs/dc1346a9f60a464584318aceb549e91d
# 🧪 View experiment at: http://localhost:5000/#/experiments/2
# [I 2026-04-03 09:48:02,537] Trial 56 finished with value: 0.9866238476867716 and parameters: {'max_depth': 3, 'learning_rate': 0.07691959789032547, 'n_estimators': 150, 'subsample': 0.734835393011126, 'colsample_bytree': 0.7731841090039139, 'min_child_weight': 4, 'gamma': 0.22546199886444263, 'reg_alpha': 0.0019304611980529157, 'reg_lambda': 0.7982695769584286}. Best is trial 13 with value: 0.9919728749408611.
# 🏃 View run trial_57 at: http://localhost:5000/#/experiments/2/runs/01023a1daf644efb9ef3c7dfddfe9aba
# 🧪 View experiment at: http://localhost:5000/#/experiments/2
# [I 2026-04-03 09:48:04,255] Trial 57 finished with value: 0.991440982924976 and parameters: {'max_depth': 3, 'learning_rate': 0.05343807374721007, 'n_estimators': 118, 'subsample': 0.7076281187170373, 'colsample_bytree': 0.7246802763691451, 'min_child_weight': 5, 'gamma': 0.24727858892585666, 'reg_alpha': 0.3101755590685227, 'reg_lambda': 0.6008160228751309}. Best is trial 13 with value: 0.9919728749408611.
# 🏃 View run trial_58 at: http://localhost:5000/#/experiments/2/runs/42ce1eac86ce4630815237a1f75ab869
# 🧪 View experiment at: http://localhost:5000/#/experiments/2
# [I 2026-04-03 09:48:06,335] Trial 58 finished with value: 0.9844833765824145 and parameters: {'max_depth': 4, 'learning_rate': 0.053849858777141046, 'n_estimators': 136, 'subsample': 0.7130136063122275, 'colsample_bytree': 0.7256578513738834, 'min_child_weight': 4, 'gamma': 0.24773626856774855, 'reg_alpha': 0.3870831665532978, 'reg_lambda': 0.6386239852119646}. Best is trial 13 with value: 0.9919728749408611.
# 🏃 View run trial_59 at: http://localhost:5000/#/experiments/2/runs/682fba465dcf41b99f7d24dfccb9a9d5
# 🧪 View experiment at: http://localhost:5000/#/experiments/2
# [I 2026-04-03 09:48:09,151] Trial 59 finished with value: 0.9898352711789078 and parameters: {'max_depth': 3, 'learning_rate': 0.05115062284355798, 'n_estimators': 159, 'subsample': 0.7224824035907119, 'colsample_bytree': 0.7095574966085412, 'min_child_weight': 5, 'gamma': 0.24501131103023388, 'reg_alpha': 0.3137930345967178, 'reg_lambda': 0.5936335221941241}. Best is trial 13 with value: 0.9919728749408611.
# 🏃 View run trial_60 at: http://localhost:5000/#/experiments/2/runs/6ad1f6c8fc2c489fb80d46e78e4273dd
# 🧪 View experiment at: http://localhost:5000/#/experiments/2
# [I 2026-04-03 09:48:11,792] Trial 60 finished with value: 0.9818095797909706 and parameters: {'max_depth': 3, 'learning_rate': 0.05681477619726502, 'n_estimators': 253, 'subsample': 0.8939892795807983, 'colsample_bytree': 0.7371209089514612, 'min_child_weight': 4, 'gamma': 0.2753601011438348, 'reg_alpha': 0.3547038487533564, 'reg_lambda': 0.5397561616478623}. Best is trial 13 with value: 0.9919728749408611.
# 🏃 View run trial_61 at: http://localhost:5000/#/experiments/2/runs/37dbaee3d0ed40688ed7ee51575b3ae8
# 🧪 View experiment at: http://localhost:5000/#/experiments/2
# [I 2026-04-03 09:48:13,486] Trial 61 finished with value: 0.9903685968659947 and parameters: {'max_depth': 3, 'learning_rate': 0.06078331851145757, 'n_estimators': 118, 'subsample': 0.7278115954237083, 'colsample_bytree': 0.761980866384474, 'min_child_weight': 5, 'gamma': 0.2308373932096864, 'reg_alpha': 0.18372178240179682, 'reg_lambda': 0.7115701545234498}. Best is trial 13 with value: 0.9919728749408611.
# 🏃 View run trial_62 at: http://localhost:5000/#/experiments/2/runs/0ce504156a464bf9bd4d9d8fe585ef7c
# 🧪 View experiment at: http://localhost:5000/#/experiments/2
# [I 2026-04-03 09:48:15,172] Trial 62 finished with value: 0.9919743086120629 and parameters: {'max_depth': 3, 'learning_rate': 0.05476671739573796, 'n_estimators': 107, 'subsample': 0.7057014451509656, 'colsample_bytree': 0.7529690896339755, 'min_child_weight': 5, 'gamma': 0.2089856783031406, 'reg_alpha': 0.08012467364391737, 'reg_lambda': 0.8333330154745322}. Best is trial 62 with value: 0.9919743086120629.
# 🏃 View run trial_63 at: http://localhost:5000/#/experiments/2/runs/e1aa7f51510748929ee1d462ba98b451
# 🧪 View experiment at: http://localhost:5000/#/experiments/2
# [I 2026-04-03 09:48:16,866] Trial 63 finished with value: 0.9919743086120629 and parameters: {'max_depth': 3, 'learning_rate': 0.05524168576118554, 'n_estimators': 104, 'subsample': 0.7096046592429864, 'colsample_bytree': 0.7480548147316185, 'min_child_weight': 5, 'gamma': 0.2148323625841893, 'reg_alpha': 0.0774229109329895, 'reg_lambda': 0.6855693518661471}. Best is trial 62 with value: 0.9919743086120629.
# 🏃 View run trial_64 at: http://localhost:5000/#/experiments/2/runs/004fa87500214d1c89f50ea9b5595266
# 🧪 View experiment at: http://localhost:5000/#/experiments/2
# [I 2026-04-03 09:48:18,546] Trial 64 finished with value: 0.9903714642083983 and parameters: {'max_depth': 3, 'learning_rate': 0.05479917601994547, 'n_estimators': 126, 'subsample': 0.706686968190279, 'colsample_bytree': 0.7250257436181419, 'min_child_weight': 5, 'gamma': 0.21019270311476168, 'reg_alpha': 0.08706711650096677, 'reg_lambda': 0.658132326780513}. Best is trial 62 with value: 0.9919743086120629.
# 🏃 View run trial_65 at: http://localhost:5000/#/experiments/2/runs/deb2a32ac6fa4cd69e2c2e74aa4aaf57
# 🧪 View experiment at: http://localhost:5000/#/experiments/2
# [I 2026-04-03 09:48:20,169] Trial 65 finished with value: 0.9925090679703518 and parameters: {'max_depth': 3, 'learning_rate': 0.05232989990345877, 'n_estimators': 100, 'subsample': 0.7089657929481501, 'colsample_bytree': 0.7442618670249532, 'min_child_weight': 5, 'gamma': 0.24237639257021928, 'reg_alpha': 0.06603912457964964, 'reg_lambda': 0.7329589321429174}. Best is trial 65 with value: 0.9925090679703518.
# 🏃 View run trial_66 at: http://localhost:5000/#/experiments/2/runs/66aaf38a51bf4e97b781722eab4bce9c
# 🧪 View experiment at: http://localhost:5000/#/experiments/2
# [I 2026-04-03 09:48:21,861] Trial 66 finished with value: 0.9930452609998422 and parameters: {'max_depth': 3, 'learning_rate': 0.050413365002653664, 'n_estimators': 106, 'subsample': 0.7093950528470447, 'colsample_bytree': 0.7458250331420245, 'min_child_weight': 5, 'gamma': 0.2863573585132243, 'reg_alpha': 0.040453102368983675, 'reg_lambda': 0.8370871815650651}. Best is trial 66 with value: 0.9930452609998422.
# 🏃 View run trial_67 at: http://localhost:5000/#/experiments/2/runs/1989976a4904494190fe7b562218b5bd
# 🧪 View experiment at: http://localhost:5000/#/experiments/2
# [I 2026-04-03 09:48:23,707] Trial 67 finished with value: 0.9930452609998422 and parameters: {'max_depth': 3, 'learning_rate': 0.05007492262978418, 'n_estimators': 106, 'subsample': 0.7068834064736067, 'colsample_bytree': 0.7459092589745131, 'min_child_weight': 5, 'gamma': 0.27973876723947927, 'reg_alpha': 0.036891670670322195, 'reg_lambda': 0.8365922223328189}. Best is trial 66 with value: 0.9930452609998422.
# 🏃 View run trial_68 at: http://localhost:5000/#/experiments/2/runs/2f84c75945e24308a153278b600d5782
# 🧪 View experiment at: http://localhost:5000/#/experiments/2
# [I 2026-04-03 09:48:25,725] Trial 68 finished with value: 0.9882281257616377 and parameters: {'max_depth': 4, 'learning_rate': 0.05225334251340942, 'n_estimators': 106, 'subsample': 0.7010930634529889, 'colsample_bytree': 0.7448286661100086, 'min_child_weight': 5, 'gamma': 0.2909166638969932, 'reg_alpha': 0.03135860025409058, 'reg_lambda': 0.8381016077539565}. Best is trial 66 with value: 0.9930452609998422.
# 🏃 View run trial_69 at: http://localhost:5000/#/experiments/2/runs/773a0e2cfdfd403d824541aee5bda95e
# 🧪 View experiment at: http://localhost:5000/#/experiments/2
# [I 2026-04-03 09:48:28,197] Trial 69 finished with value: 0.9855528952989921 and parameters: {'max_depth': 3, 'learning_rate': 0.05135933642411633, 'n_estimators': 218, 'subsample': 0.7109756566273314, 'colsample_bytree': 0.7524427825622093, 'min_child_weight': 5, 'gamma': 0.2847656728174182, 'reg_alpha': 0.040917626482912486, 'reg_lambda': 0.7288618565575572}. Best is trial 66 with value: 0.9930452609998422.
# 🏃 View run trial_70 at: http://localhost:5000/#/experiments/2/runs/1a1737accbc24a55886c3669d5055efa
# 🧪 View experiment at: http://localhost:5000/#/experiments/2
# [I 2026-04-03 09:48:30,024] Trial 70 finished with value: 0.9834138578658369 and parameters: {'max_depth': 5, 'learning_rate': 0.050228602260745804, 'n_estimators': 105, 'subsample': 0.7066803681235855, 'colsample_bytree': 0.736763188384136, 'min_child_weight': 5, 'gamma': 0.26347443571035106, 'reg_alpha': 0.15273622792375063, 'reg_lambda': 0.8630716816974853}. Best is trial 66 with value: 0.9930452609998422.
# 🏃 View run trial_71 at: http://localhost:5000/#/experiments/2/runs/594b22366e454a798744a5e7245b9774
# 🧪 View experiment at: http://localhost:5000/#/experiments/2
# [I 2026-04-03 09:48:31,746] Trial 71 finished with value: 0.9914395492537741 and parameters: {'max_depth': 3, 'learning_rate': 0.05293922256827235, 'n_estimators': 116, 'subsample': 0.7074503007563933, 'colsample_bytree': 0.7477589240515948, 'min_child_weight': 5, 'gamma': 0.28249186836421014, 'reg_alpha': 0.02485196002999565, 'reg_lambda': 0.7749741975727595}. Best is trial 66 with value: 0.9930452609998422.
# 🏃 View run trial_72 at: http://localhost:5000/#/experiments/2/runs/3dff46c4342a49949ea063207120d9e7
# 🧪 View experiment at: http://localhost:5000/#/experiments/2
# [I 2026-04-03 09:48:33,458] Trial 72 finished with value: 0.9909033562242835 and parameters: {'max_depth': 3, 'learning_rate': 0.05834413880830677, 'n_estimators': 113, 'subsample': 0.713736018977497, 'colsample_bytree': 0.7183712009318832, 'min_child_weight': 5, 'gamma': 0.2541919172245855, 'reg_alpha': 0.06300136393570538, 'reg_lambda': 0.8178901843093586}. Best is trial 66 with value: 0.9930452609998422.
# 🏃 View run trial_73 at: http://localhost:5000/#/experiments/2/runs/7fcf136a31c443a193cb97522e7598d0
# 🧪 View experiment at: http://localhost:5000/#/experiments/2
# [I 2026-04-03 09:48:35,099] Trial 73 finished with value: 0.9935814540293328 and parameters: {'max_depth': 3, 'learning_rate': 0.050033819873641174, 'n_estimators': 100, 'subsample': 0.720943883811227, 'colsample_bytree': 0.742722089480143, 'min_child_weight': 5, 'gamma': 0.24215581054293728, 'reg_alpha': 0.0649039002513156, 'reg_lambda': 0.6813345549631264}. Best is trial 73 with value: 0.9935814540293328.
# 🏃 View run trial_74 at: http://localhost:5000/#/experiments/2/runs/31a974a3677d4a50962bcc6a207c4b0c
# 🧪 View experiment at: http://localhost:5000/#/experiments/2
# [I 2026-04-03 09:48:36,718] Trial 74 finished with value: 0.9919743086120629 and parameters: {'max_depth': 3, 'learning_rate': 0.05662053210739679, 'n_estimators': 104, 'subsample': 0.7206301226313228, 'colsample_bytree': 0.7427467232254398, 'min_child_weight': 5, 'gamma': 0.2630392412859605, 'reg_alpha': 0.1125721243965182, 'reg_lambda': 0.7035716358571892}. Best is trial 73 with value: 0.9935814540293328.
# 🏃 View run trial_75 at: http://localhost:5000/#/experiments/2/runs/5fe732b2531549898ecf8a8221993324
# 🧪 View experiment at: http://localhost:5000/#/experiments/2
# [I 2026-04-03 09:48:38,326] Trial 75 finished with value: 0.9930452609998422 and parameters: {'max_depth': 3, 'learning_rate': 0.05006908443807605, 'n_estimators': 106, 'subsample': 0.7165246169312518, 'colsample_bytree': 0.752709696046711, 'min_child_weight': 5, 'gamma': 0.2661132565825933, 'reg_alpha': 0.12049287305025885, 'reg_lambda': 0.6883830509996065}. Best is trial 73 with value: 0.9935814540293328.
# 🏃 View run trial_76 at: http://localhost:5000/#/experiments/2/runs/6efa4e5db8c941278c09d28437c4933d
# 🧪 View experiment at: http://localhost:5000/#/experiments/2
# [I 2026-04-03 09:48:39,965] Trial 76 finished with value: 0.9930452609998422 and parameters: {'max_depth': 3, 'learning_rate': 0.05007868873414583, 'n_estimators': 100, 'subsample': 0.7192289913256917, 'colsample_bytree': 0.7502053444356519, 'min_child_weight': 5, 'gamma': 0.26416390662155953, 'reg_alpha': 0.11655074941336019, 'reg_lambda': 0.6875496973692131}. Best is trial 73 with value: 0.9935814540293328.
# 🏃 View run trial_77 at: http://localhost:5000/#/experiments/2/runs/a2fd52efd023439684c6d6f4ee832920
# 🧪 View experiment at: http://localhost:5000/#/experiments/2
# [I 2026-04-03 09:48:41,575] Trial 77 finished with value: 0.9925105016415536 and parameters: {'max_depth': 3, 'learning_rate': 0.05006717031140409, 'n_estimators': 110, 'subsample': 0.7150419770540521, 'colsample_bytree': 0.7558659848495562, 'min_child_weight': 5, 'gamma': 0.28572205345749196, 'reg_alpha': 0.07390201573133916, 'reg_lambda': 0.6791002319967665}. Best is trial 73 with value: 0.9935814540293328.
# 🏃 View run trial_78 at: http://localhost:5000/#/experiments/2/runs/da7612e735cb4582aeae8e9bbe8a3fe1
# 🧪 View experiment at: http://localhost:5000/#/experiments/2
# [I 2026-04-03 09:48:43,721] Trial 78 finished with value: 0.9737824547318319 and parameters: {'max_depth': 6, 'learning_rate': 0.05154585575875801, 'n_estimators': 130, 'subsample': 0.7162474043695561, 'colsample_bytree': 0.7547365725136641, 'min_child_weight': 5, 'gamma': 0.2990670728250542, 'reg_alpha': 0.13240570495112555, 'reg_lambda': 0.5595940772586656}. Best is trial 73 with value: 0.9935814540293328.
# 🏃 View run trial_79 at: http://localhost:5000/#/experiments/2/runs/618b1debd277412ba6ec469f5490d9a5
# 🧪 View experiment at: http://localhost:5000/#/experiments/2
# [I 2026-04-03 09:48:45,406] Trial 79 finished with value: 0.9919743086120629 and parameters: {'max_depth': 3, 'learning_rate': 0.05030260863781435, 'n_estimators': 111, 'subsample': 0.729942920248878, 'colsample_bytree': 0.7790210169112781, 'min_child_weight': 5, 'gamma': 0.2689215481286073, 'reg_alpha': 0.02479739454956091, 'reg_lambda': 0.7431434785878673}. Best is trial 73 with value: 0.9935814540293328.
# 🏃 View run trial_80 at: http://localhost:5000/#/experiments/2/runs/8d74387b29df437396ab0e1259190e03
# 🧪 View experiment at: http://localhost:5000/#/experiments/2
# [I 2026-04-03 09:48:47,219] Trial 80 finished with value: 0.991440982924976 and parameters: {'max_depth': 3, 'learning_rate': 0.05232626002887737, 'n_estimators': 123, 'subsample': 0.7003427777512332, 'colsample_bytree': 0.7380311310321446, 'min_child_weight': 5, 'gamma': 0.2822423103969842, 'reg_alpha': 0.06474532030633898, 'reg_lambda': 0.5149597136521561}. Best is trial 73 with value: 0.9935814540293328.
# 🏃 View run trial_81 at: http://localhost:5000/#/experiments/2/runs/16aaa5053ca3429ab0297c8d4650e87a
# 🧪 View experiment at: http://localhost:5000/#/experiments/2
# [I 2026-04-03 09:48:48,827] Trial 81 finished with value: 0.9941176470588236 and parameters: {'max_depth': 3, 'learning_rate': 0.050365476345632446, 'n_estimators': 100, 'subsample': 0.7129143580368381, 'colsample_bytree': 0.7540714375825819, 'min_child_weight': 5, 'gamma': 0.2872669701734525, 'reg_alpha': 0.07338364000860315, 'reg_lambda': 0.6835022501206511}. Best is trial 81 with value: 0.9941176470588236.
# 🏃 View run trial_82 at: http://localhost:5000/#/experiments/2/runs/586eeafe5f8b420eb9c92df12371b4c3
# 🧪 View experiment at: http://localhost:5000/#/experiments/2
# [I 2026-04-03 09:48:50,523] Trial 82 finished with value: 0.9930452609998422 and parameters: {'max_depth': 3, 'learning_rate': 0.05004179622574345, 'n_estimators': 101, 'subsample': 0.7160569729597984, 'colsample_bytree': 0.7521877971025117, 'min_child_weight': 5, 'gamma': 0.2897377479401072, 'reg_alpha': 0.11076752855387065, 'reg_lambda': 0.6691267575680873}. Best is trial 81 with value: 0.9941176470588236.
# 🏃 View run trial_83 at: http://localhost:5000/#/experiments/2/runs/ded7d7ae54a14224a9dee95d8df9373d
# 🧪 View experiment at: http://localhost:5000/#/experiments/2
# [I 2026-04-03 09:48:52,135] Trial 83 finished with value: 0.9925105016415536 and parameters: {'max_depth': 3, 'learning_rate': 0.05018808560201366, 'n_estimators': 100, 'subsample': 0.7256244375171133, 'colsample_bytree': 0.7662202074437562, 'min_child_weight': 5, 'gamma': 0.2901869983960259, 'reg_alpha': 0.11890579487684683, 'reg_lambda': 0.5879070577429579}. Best is trial 81 with value: 0.9941176470588236.
# 🏃 View run trial_84 at: http://localhost:5000/#/experiments/2/runs/54a4728b04bc49f8bac16a982fa2c4fa
# 🧪 View experiment at: http://localhost:5000/#/experiments/2
# [I 2026-04-03 09:48:53,861] Trial 84 finished with value: 0.9925105016415536 and parameters: {'max_depth': 3, 'learning_rate': 0.05033366337063685, 'n_estimators': 113, 'subsample': 0.7237300527803784, 'colsample_bytree': 0.7670513563929725, 'min_child_weight': 5, 'gamma': 0.2917341899071255, 'reg_alpha': 0.16189680717389104, 'reg_lambda': 0.6579072021004106}. Best is trial 81 with value: 0.9941176470588236.
# 🏃 View run trial_85 at: http://localhost:5000/#/experiments/2/runs/c1f6df180dcc4f6292b2e32a730d3da4
# 🧪 View experiment at: http://localhost:5000/#/experiments/2
# [I 2026-04-03 09:48:55,504] Trial 85 finished with value: 0.9914381155825722 and parameters: {'max_depth': 3, 'learning_rate': 0.053301831631113676, 'n_estimators': 105, 'subsample': 0.7154843323917894, 'colsample_bytree': 0.7597822902662154, 'min_child_weight': 5, 'gamma': 0.299595178502542, 'reg_alpha': 0.10777675053653205, 'reg_lambda': 0.6108409537673747}. Best is trial 81 with value: 0.9941176470588236.
# 🏃 View run trial_86 at: http://localhost:5000/#/experiments/2/runs/aea21f1dff444b92a45db5efe1b09538
# 🧪 View experiment at: http://localhost:5000/#/experiments/2
# [I 2026-04-03 09:48:57,121] Trial 86 finished with value: 0.9930452609998422 and parameters: {'max_depth': 3, 'learning_rate': 0.050117585208548455, 'n_estimators': 100, 'subsample': 0.7323869991873202, 'colsample_bytree': 0.7561589459422451, 'min_child_weight': 5, 'gamma': 0.28663169976782693, 'reg_alpha': 0.040741319319850935, 'reg_lambda': 0.5848465949294501}. Best is trial 81 with value: 0.9941176470588236.
# 🏃 View run trial_87 at: http://localhost:5000/#/experiments/2/runs/de999139f0804f8e9ec72f31812fa572
# 🧪 View experiment at: http://localhost:5000/#/experiments/2
# [I 2026-04-03 09:48:58,914] Trial 87 finished with value: 0.9919743086120629 and parameters: {'max_depth': 3, 'learning_rate': 0.051547183602988156, 'n_estimators': 118, 'subsample': 0.7319587018565211, 'colsample_bytree': 0.7561197955499211, 'min_child_weight': 5, 'gamma': 0.2751128000478391, 'reg_alpha': 0.04268621926002116, 'reg_lambda': 0.5093227000598203}. Best is trial 81 with value: 0.9941176470588236.
# 🏃 View run trial_88 at: http://localhost:5000/#/experiments/2/runs/1dae4449baf24d5fba82cd9dcb8b42d5
# 🧪 View experiment at: http://localhost:5000/#/experiments/2
# [I 2026-04-03 09:49:00,666] Trial 88 finished with value: 0.9914395492537741 and parameters: {'max_depth': 3, 'learning_rate': 0.05384381935733422, 'n_estimators': 111, 'subsample': 0.7189199482093432, 'colsample_bytree': 0.7513108305787933, 'min_child_weight': 5, 'gamma': 0.2821052223392042, 'reg_alpha': 0.011421861861948046, 'reg_lambda': 0.6869840530642227}. Best is trial 81 with value: 0.9941176470588236.
# 🏃 View run trial_89 at: http://localhost:5000/#/experiments/2/runs/c1d4c53695ea4a2bac6d66eb91c6ad9a
# 🧪 View experiment at: http://localhost:5000/#/experiments/2
# [I 2026-04-03 09:49:02,640] Trial 89 finished with value: 0.9844819429112126 and parameters: {'max_depth': 3, 'learning_rate': 0.10263539100135263, 'n_estimators': 121, 'subsample': 0.7144219329077329, 'colsample_bytree': 0.8602692770847096, 'min_child_weight': 5, 'gamma': 0.2563159181368857, 'reg_alpha': 0.13960043018877905, 'reg_lambda': 0.7847885247095088}. Best is trial 81 with value: 0.9941176470588236.
# 🏃 View run trial_90 at: http://localhost:5000/#/experiments/2/runs/fc08983d93af434ca64112e372771002
# 🧪 View experiment at: http://localhost:5000/#/experiments/2
# [I 2026-04-03 09:49:04,383] Trial 90 finished with value: 0.9909047898954852 and parameters: {'max_depth': 3, 'learning_rate': 0.05001767568533241, 'n_estimators': 109, 'subsample': 0.7277869418192696, 'colsample_bytree': 0.736710270211333, 'min_child_weight': 5, 'gamma': 0.2668525146078138, 'reg_alpha': 0.046940099513879056, 'reg_lambda': 1.3509564087288257}. Best is trial 81 with value: 0.9941176470588236.
# 🏃 View run trial_91 at: http://localhost:5000/#/experiments/2/runs/20a34da70aca4cb0accf50086be765d5
# 🧪 View experiment at: http://localhost:5000/#/experiments/2
# [I 2026-04-03 09:49:06,221] Trial 91 finished with value: 0.9930452609998422 and parameters: {'max_depth': 3, 'learning_rate': 0.051551521764088164, 'n_estimators': 100, 'subsample': 0.7234607303596662, 'colsample_bytree': 0.763813014588344, 'min_child_weight': 5, 'gamma': 0.28814850562112637, 'reg_alpha': 0.10679799632453775, 'reg_lambda': 0.5874141484036948}. Best is trial 81 with value: 0.9941176470588236.
# 🏃 View run trial_92 at: http://localhost:5000/#/experiments/2/runs/0d7bba2b04264118ba4d78fd48010be9
# 🧪 View experiment at: http://localhost:5000/#/experiments/2
# [I 2026-04-03 09:49:07,811] Trial 92 finished with value: 0.9919743086120629 and parameters: {'max_depth': 3, 'learning_rate': 0.0516432968306294, 'n_estimators': 104, 'subsample': 0.7203671133869316, 'colsample_bytree': 0.7763271790180226, 'min_child_weight': 5, 'gamma': 0.27796516660612036, 'reg_alpha': 0.10843935741435315, 'reg_lambda': 0.5738697433008688}. Best is trial 81 with value: 0.9941176470588236.
# 🏃 View run trial_93 at: http://localhost:5000/#/experiments/2/runs/601b7537aad04449b495a0665fe08e00
# 🧪 View experiment at: http://localhost:5000/#/experiments/2
# [I 2026-04-03 09:49:09,458] Trial 93 finished with value: 0.9834124241946351 and parameters: {'max_depth': 3, 'learning_rate': 0.13031053083556604, 'n_estimators': 114, 'subsample': 0.7033159502237141, 'colsample_bytree': 0.7633126694995666, 'min_child_weight': 5, 'gamma': 0.28645342705329996, 'reg_alpha': 0.1748038095079285, 'reg_lambda': 0.636235768852924}. Best is trial 81 with value: 0.9941176470588236.
# 🏃 View run trial_94 at: http://localhost:5000/#/experiments/2/runs/caca3dc7dc524b3f8f12b255d0cb1c15
# 🧪 View experiment at: http://localhost:5000/#/experiments/2
# [I 2026-04-03 09:49:11,017] Trial 94 finished with value: 0.9935785866869292 and parameters: {'max_depth': 3, 'learning_rate': 0.05311796588808557, 'n_estimators': 100, 'subsample': 0.7372163108590105, 'colsample_bytree': 0.7576652101744287, 'min_child_weight': 5, 'gamma': 0.27167137803019575, 'reg_alpha': 0.02173307896374725, 'reg_lambda': 0.5338016829602138}. Best is trial 81 with value: 0.9941176470588236.
# 🏃 View run trial_95 at: http://localhost:5000/#/experiments/2/runs/b37d312b649044be8cd45b69a6bde9e2
# 🧪 View experiment at: http://localhost:5000/#/experiments/2
# [I 2026-04-03 09:49:12,614] Trial 95 finished with value: 0.9930438273286404 and parameters: {'max_depth': 3, 'learning_rate': 0.052961814491654144, 'n_estimators': 100, 'subsample': 0.7365955278218882, 'colsample_bytree': 0.7706840783645282, 'min_child_weight': 5, 'gamma': 0.2707959438990726, 'reg_alpha': 0.001245900230989326, 'reg_lambda': 0.5358653742346953}. Best is trial 81 with value: 0.9941176470588236.
# 🏃 View run trial_96 at: http://localhost:5000/#/experiments/2/runs/7546b71397b341ac8f5d7f7e39d49159
# 🧪 View experiment at: http://localhost:5000/#/experiments/2
# [I 2026-04-03 09:49:14,422] Trial 96 finished with value: 0.9919743086120629 and parameters: {'max_depth': 3, 'learning_rate': 0.05145509556925373, 'n_estimators': 125, 'subsample': 0.7485140121870667, 'colsample_bytree': 0.7499116241457672, 'min_child_weight': 5, 'gamma': 0.2601336373137967, 'reg_alpha': 0.029348820860208416, 'reg_lambda': 0.5323331017617707}. Best is trial 81 with value: 0.9941176470588236.
# 🏃 View run trial_97 at: http://localhost:5000/#/experiments/2/runs/72357d6362154b2f8af3cc0a3ddccc43
# 🧪 View experiment at: http://localhost:5000/#/experiments/2
# [I 2026-04-03 09:49:16,061] Trial 97 finished with value: 0.9930452609998422 and parameters: {'max_depth': 3, 'learning_rate': 0.053716169097962674, 'n_estimators': 105, 'subsample': 0.734078256199047, 'colsample_bytree': 0.7409454942717939, 'min_child_weight': 5, 'gamma': 0.29212576689840325, 'reg_alpha': 0.0994050949089038, 'reg_lambda': 0.579953526720748}. Best is trial 81 with value: 0.9941176470588236.
# 🏃 View run trial_98 at: http://localhost:5000/#/experiments/2/runs/dd97660a28e94146aa6044ed01f3bef5
# 🧪 View experiment at: http://localhost:5000/#/experiments/2
# [I 2026-04-03 09:49:18,211] Trial 98 finished with value: 0.9887643187911284 and parameters: {'max_depth': 3, 'learning_rate': 0.05587954329501926, 'n_estimators': 174, 'subsample': 0.7401648123410051, 'colsample_bytree': 0.7795315265427123, 'min_child_weight': 5, 'gamma': 0.27907638932111833, 'reg_alpha': 0.05234368997893554, 'reg_lambda': 0.6207585217693905}. Best is trial 81 with value: 0.9941176470588236.
# 🏃 View run trial_99 at: http://localhost:5000/#/experiments/2/runs/6cd26026bcb345778c20d9285d0df13a
# 🧪 View experiment at: http://localhost:5000/#/experiments/2
# [I 2026-04-03 09:49:19,939] Trial 99 finished with value: 0.9914381155825722 and parameters: {'max_depth': 3, 'learning_rate': 0.05708719764799662, 'n_estimators': 117, 'subsample': 0.7296983910573108, 'colsample_bytree': 0.791394331488758, 'min_child_weight': 5, 'gamma': 0.25832425111512086, 'reg_alpha': 0.1435043770785569, 'reg_lambda': 1.8542673580955962}. Best is trial 81 with value: 0.9941176470588236.
#
# ✅ Optimization Complete!
# ⏱️  Duration: 3.2 minutes
# 📊 Total Trials: 100
# ✅ Successful: 100

# %%
# === 9. Best Trial Results ===
print("\n🏆 Best Trial Results")
print("=" * 60)

best_trial = study.best_trial
best_params = best_trial.params
best_recall = float(best_trial.value)  # ✅ Convert to float

print(f"📊 Best Recall: {best_recall:.4f}")
print(f"🎯 Baseline Recall: {baseline_recall:.4f}")
print(f"📈 Improvement: {(best_recall - baseline_recall) * 100:.2f}%")

print(f"\n📋 Best Hyperparameters:")
for k, v in best_params.items():
    print(f"   - {k}: {v}")

# Save results
# ✅ FIX 1: Use project root artifacts directory
artifacts_dir = Path.cwd().parent.parent / 'artifacts'
artifacts_dir.mkdir(exist_ok=True)

# ✅ FIX 2: Convert numpy types to Python native types
tuning_results = {
    'best_recall': float(best_recall),
    'baseline_recall': float(baseline_recall),
    'improvement': float(best_recall - baseline_recall),
    'best_params': {k: (float(v) if isinstance(v, (np.floating, np.integer)) else v) 
                    for k, v in best_params.items()},
    'n_trials': len(study.trials),
    'generated_at': datetime.now().isoformat()
}

with open(artifacts_dir / 'tuning_results.json', 'w') as f:
    json.dump(tuning_results, f, indent=2)

print(f"\n💾 Results saved to: {artifacts_dir / 'tuning_results.json'}")

# ✅ FIX 3: Verify baseline was loaded
print(f"\n🔍 Baseline Verification:")
if baseline_path.exists():
    print(f"   ✅ Baseline loaded from: {baseline_path}")
else:
    print(f"   ⚠️  Baseline not found, using default: {baseline_recall:.4f}")
# Out:
# 🏆 Best Trial Results
# ============================================================
# 📊 Best Recall: 0.9941
# 🎯 Baseline Recall: 0.9780
# 📈 Improvement: 1.61%
#
# 📋 Best Hyperparameters:
#    - max_depth: 3
#    - learning_rate: 0.050365476345632446
#    - n_estimators: 100
#    - subsample: 0.7129143580368381
#    - colsample_bytree: 0.7540714375825819
#    - min_child_weight: 5
#    - gamma: 0.2872669701734525
#    - reg_alpha: 0.07338364000860315
#    - reg_lambda: 0.6835022501206511
#
# 💾 Results saved to: C:\Users\user\Desktop\Library\Work\Journey to Agentic_AI MLOps\Files\E2E project\Project churn\churn-scratch\Telco churn\artifacts\tuning_results.json
#
# 🔍 Baseline Verification:
#    ✅ Baseline loaded from: ..\..\artifacts\training_summary.json

# %%
# === 10. Visualizations ===
print("\n📊 Generating Visualizations...")

# Ensure artifacts directory exists
artifacts_dir.mkdir(parents=True, exist_ok=True)

# Set better plotting style
plt.style.use('seaborn-v0_8-whitegrid')
plt.rcParams['figure.dpi'] = 100
plt.rcParams['savefig.dpi'] = 300
plt.rcParams['font.size'] = 10
plt.rcParams['axes.titlesize'] = 14
plt.rcParams['axes.labelsize'] = 12

# 1. Optimization History
print("   Creating optimization history plot...")
ax_history = optuna.visualization.matplotlib.plot_optimization_history(study)
ax_history.set_title('Optimization History', fontsize=14, fontweight='bold', pad=20)
ax_history.figure.tight_layout()
ax_history.figure.savefig(artifacts_dir / 'optimization_history.png', dpi=300, bbox_inches='tight')
plt.close(ax_history.figure)

# 2. Parameter Importances
print("   Creating parameter importances plot...")
ax_importance = optuna.visualization.matplotlib.plot_param_importances(study)
ax_importance.set_title('Parameter Importances', fontsize=14, fontweight='bold', pad=20)
ax_importance.figure.tight_layout()
ax_importance.figure.savefig(artifacts_dir / 'param_importances.png', dpi=300, bbox_inches='tight')
plt.close(ax_importance.figure)

# 3. Parallel Coordinate
print("   Creating parallel coordinate plot...")
ax_parallel = optuna.visualization.matplotlib.plot_parallel_coordinate(study)
ax_parallel.set_title('Parallel Coordinate', fontsize=14, fontweight='bold', pad=20)
ax_parallel.figure.tight_layout()
ax_parallel.figure.savefig(artifacts_dir / 'parallel_coordinate.png', dpi=300, bbox_inches='tight')
plt.close(ax_parallel.figure)

# 4. Recall vs Precision Scatter (Custom)
print("   Creating recall vs precision scatter plot...")
recalls = [t.value for t in study.trials if t.value > 0]
precisions = [t.user_attrs.get('precision_mean', 0) for t in study.trials if t.value > 0]

fig_scatter, ax_scatter = plt.subplots(figsize=(10, 6))
scatter = ax_scatter.scatter(precisions, recalls, alpha=0.6, c=recalls, cmap='viridis', s=50, edgecolors='black', linewidth=0.5)
ax_scatter.axvline(x=MIN_PRECISION, color='red', linestyle='--', linewidth=2, label=f'Min Precision ({MIN_PRECISION})')
ax_scatter.axhline(y=baseline_recall, color='orange', linestyle='--', linewidth=2, label=f'Baseline ({baseline_recall:.3f})')
ax_scatter.set_xlabel('Precision', fontsize=12, fontweight='bold')
ax_scatter.set_ylabel('Recall', fontsize=12, fontweight='bold')
ax_scatter.set_title('Trial Results: Recall vs Precision', fontsize=14, fontweight='bold', pad=20)
ax_scatter.legend(loc='lower right', fontsize=10)
ax_scatter.grid(True, alpha=0.3)
cbar = plt.colorbar(scatter, ax=ax_scatter)
cbar.set_label('Recall', fontsize=11, fontweight='bold')

# Add best trial annotation
if len(recalls) > 0:
    best_idx = np.argmax(recalls)
    ax_scatter.annotate(f'Best\nRecall: {recalls[best_idx]:.3f}', 
                xy=(precisions[best_idx], recalls[best_idx]), 
                xytext=(10, 10), textcoords='offset points',
                bbox=dict(boxstyle='round,pad=0.5', fc='yellow', alpha=0.7),
                arrowprops=dict(arrowstyle='->', connectionstyle='arc3,rad=0', color='red', lw=2),
                fontsize=10, fontweight='bold')

plt.tight_layout()
plt.savefig(artifacts_dir / 'recall_precision_scatter.png', dpi=300, bbox_inches='tight')
plt.show()
plt.close(fig_scatter)

print(f"✅ Visualizations saved to: {artifacts_dir}")
print(f"   - optimization_history.png")
print(f"   - param_importances.png")
print(f"   - parallel_coordinate.png")
print(f"   - recall_precision_scatter.png")
# Out:
# 📊 Generating Visualizations...
#    Creating optimization history plot...
#    Creating parameter importances plot...
#    Creating parallel coordinate plot...
#    Creating recall vs precision scatter plot...
# ✅ Visualizations saved to: C:\Users\user\Desktop\Library\Work\Journey to Agentic_AI MLOps\Files\E2E project\Project churn\churn-scratch\Telco churn\artifacts
#    - optimization_history.png
#    - param_importances.png
#    - parallel_coordinate.png
#    - recall_precision_scatter.png

# %%
# === 11. Train Final Model ===
print("\n🎯 Training Final Model with Best Params...")

final_params = best_params.copy()
final_params.update({
    'objective': 'binary:logistic',
    'eval_metric': 'logloss',
    'scale_pos_weight': scale_pos_weight,
    'random_state': RANDOM_STATE,
    'n_jobs': -1
})

final_model = xgb.XGBClassifier(**final_params)
final_model.fit(X, y, verbose=False)

print(f"✅ Final model trained")

best_trial_idx = best_trial.number
best_trial_data = trial_results[best_trial_idx]
best_recall = best_trial_data['recall']
best_precision = best_trial_data['precision']


# Log to MLflow
with mlflow.start_run(run_name="best_tuned_model"):
    mlflow.log_params(final_params)
    
    # ✅ Log ALL three metrics
    mlflow.log_metric("recall", best_recall)
    mlflow.log_metric("precision", best_precision)
   
    
    # ✅ Also log improvement over baseline
    mlflow.log_metric("recall_improvement", best_recall - baseline_recall)
    mlflow.log_metric("precision_improvement", best_precision - 0.35)  # vs min constraint
    
    from mlflow.models.signature import infer_signature
    signature = infer_signature(X.head(1), final_model.predict_proba(X.head(1))[:, 1])
    
    mlflow.xgboost.log_model(
        final_model,
        artifact_path="model",
        signature=signature,
        registered_model_name=f"{settings.model_registry_name}_tuned"
    )
    
    print(f"✅ Model logged to MLflow Registry")
    print(f"📊 Metrics logged:")
    print(f"   - Recall: {best_recall:.4f}")
    print(f"   - Precision: {best_precision:.4f}")
# Out:
# 🎯 Training Final Model with Best Params...
# ✅ Final model trained
# 2026/04/03 10:38:22 WARNING mlflow.models.model: `artifact_path` is deprecated. Please use `name` instead.
# Successfully registered model 'telco_churn_model_tuned'.
# 2026/04/03 10:38:35 INFO mlflow.store.model_registry.abstract_store: Waiting up to 300 seconds for model version to finish creation. Model name: telco_churn_model_tuned, version 1
# Created version '1' of model 'telco_churn_model_tuned'.
# ✅ Model logged to MLflow Registry
# 📊 Metrics logged:
#    - Recall: 0.9941
#    - Precision: 0.3790
# 🏃 View run best_tuned_model at: http://localhost:5000/#/experiments/2/runs/6b6cc890a1194584855d6205493d097d
# 🧪 View experiment at: http://localhost:5000/#/experiments/2

# %%
# === 12. Summary ===
print("\n" + "=" * 60)
print("📋 TUNING SUMMARY")
print("=" * 60)

print(f"""
   - Total Trials: {len(study.trials)}
   - Best Recall: {best_recall:.4f}
   - Baseline Recall: {baseline_recall:.4f}
   - Improvement: {(best_recall - baseline_recall) * 100:.2f}%
   - Precision Constraint: ≥ {MIN_PRECISION}
   - Model Registry: {settings.model_registry_name}_tuned
""")
# Out:
# ============================================================
# 📋 TUNING SUMMARY
# ============================================================
#
#    - Total Trials: 100
#    - Best Recall: 0.9941
#    - Baseline Recall: 0.9780
#    - Improvement: 1.61%
#    - Precision Constraint: ≥ 0.35
#    - Model Registry: telco_churn_model_tuned

# %% [markdown]
# ## ✅ Next Steps
#
# 1. Review MLflow UI: http://localhost:5000
# 2. Compare baseline vs tuned models
# 3. Deploy tuned model to staging
# 4. A/B test in production
#
# ---
# *Notebook for Telco Churn MLOps Project*
